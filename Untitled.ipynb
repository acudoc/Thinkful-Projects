# %% [markdown]
# # Prep Course Capstone Project

# %% [markdown]
# ## By Cassidy Dobratz
# Thinkful Data Science Bootcamp

# %% [markdown]
# #### Import the tools needed for this report.

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.patches as patches
# %matplotlib inline
import datetime, warnings, scipy
import seaborn as sns

# %% [markdown]
# #### The data set
# Can be found at https://www.kaggle.com/usdot/flight-delays/data
#
# About the data
#
# The U.S. Department of Transportation's (DOT) Bureau of Transportation Statistics tracks the on-time performance of domestic flights operated by large air carriers. The data has columns of information on the number of on-time, delayed, canceled, and diverted flights is published in DOT's monthly Air Travel Consumer Report and in this dataset of 2015 flight delays and cancellations.  The flight delay and cancellation data was collected and published by the DOT's Bureau of Transportation Statistics.

# %% [markdown]
# ##### First I upload the files into this notebook

# %%
df = pd.read_csv('flights.csv')

# %%
airlines_names = pd.read_csv('airlines.csv')

# %%
airport_names = pd.read_csv('airports.csv')

# %% [markdown]
# ##### The intial inspection of the data

# %%
df.head()
# Out:
#    YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0  2015      1    1            4      AS             98      N407AS
# 1  2015      1    1            4      AA           2336      N3KUAA
# 2  2015      1    1            4      US            840      N171US
# 3  2015      1    1            4      AA            258      N3HYAA
# 4  2015      1    1            4      AS            135      N527AS
#
#   ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE      ...        \
# 0            ANC                 SEA                    5      ...
# 1            LAX                 PBI                   10      ...
# 2            SFO                 CLT                   20      ...
# 3            LAX                 MIA                   20      ...
# 4            SEA                 ANC                   25      ...
#
#    ARRIVAL_TIME  ARRIVAL_DELAY  DIVERTED  CANCELLED  CANCELLATION_REASON  \
# 0         408.0          -22.0         0          0                  NaN
# 1         741.0           -9.0         0          0                  NaN
# 2         811.0            5.0         0          0                  NaN
# 3         756.0           -9.0         0          0                  NaN
# 4         259.0          -21.0         0          0                  NaN
#
#    AIR_SYSTEM_DELAY  SECURITY_DELAY  AIRLINE_DELAY  LATE_AIRCRAFT_DELAY  \
# 0               NaN             NaN            NaN                  NaN
# 1               NaN             NaN            NaN                  NaN
# 2               NaN             NaN            NaN                  NaN
# 3               NaN             NaN            NaN                  NaN
# 4               NaN             NaN            NaN                  NaN
#
#    WEATHER_DELAY
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#
# [5 rows x 31 columns]

# %% [markdown]
# ###### I begin to change the data to make it easier to work with.
# 1) I want to combine some columns and set the date.
# 2) Then make a function for the time and date to be displayed.

# %%
df['DATE'] = pd.to_datetime(df[['YEAR','MONTH', 'DAY']])

# %%
def format_heure(chaine):
    if pd.isnull(chaine):
        return np.nan
    else:
        if chaine == 2400: chaine = 0
        chaine = "{0:04d}".format(int(chaine))
        heure = datetime.time(int(chaine[0:2]), int(chaine[2:4]))
        return heure
# Function that combines a date and time to produce a datetime.datetime
def combine_date_heure(x):
    if pd.isnull(x[0]) or pd.isnull(x[1]):
        return np.nan
    else:
        return datetime.datetime.combine(x[0],x[1])
# Function that combine two columns of the dataframe to create a datetime format
def create_flight_time(df, col):    
    liste = []
    for index, cols in df[['DATE', col]].iterrows():    
        if pd.isnull(cols[1]):
            liste.append(np.nan)
        elif float(cols[1]) == 2400:
            cols[0] += datetime.timedelta(days=1)
            cols[1] = datetime.time(0,0)
            liste.append(combine_date_heure(cols))
        else:
            cols[1] = format_heure(cols[1])
            liste.append(combine_date_heure(cols))
    return pd.Series(liste)

# %% [markdown]
# 3) Next, I will reduce the data set columns. Keeping only columns that will be used.

# %% [markdown]
# 4) I will write a function to help get stats from columns, when I use groupy

# %%
# function that extract statistical parameters from a grouby objet:
def get_stats(group):
    return {'min': group.min(), 'max': group.max(),
            'count': group.count(), 'mean': group.mean()}

# %%
df['SCHEDULED_DEPARTURE'] = create_flight_time(df, 'SCHEDULED_DEPARTURE')
df['DEPARTURE_TIME'] = df['DEPARTURE_TIME'].apply(format_heure)
df['SCHEDULED_ARRIVAL'] = df['SCHEDULED_ARRIVAL'].apply(format_heure)
df['ARRIVAL_TIME'] = df['ARRIVAL_TIME'].apply(format_heure)
#__________________________________________________________________________
df.loc[:5, ['SCHEDULED_DEPARTURE', 'SCHEDULED_ARRIVAL', 'DEPARTURE_TIME',
             'ARRIVAL_TIME', 'DEPARTURE_DELAY', 'ARRIVAL_DELAY']]
# Out:
#   SCHEDULED_DEPARTURE SCHEDULED_ARRIVAL DEPARTURE_TIME ARRIVAL_TIME  \
# 0 2015-01-01 00:05:00          04:30:00       23:54:00     04:08:00
# 1 2015-01-01 00:10:00          07:50:00       00:02:00     07:41:00
# 2 2015-01-01 00:20:00          08:06:00       00:18:00     08:11:00
# 3 2015-01-01 00:20:00          08:05:00       00:15:00     07:56:00
# 4 2015-01-01 00:25:00          03:20:00       00:24:00     02:59:00
# 5 2015-01-01 00:25:00          06:02:00       00:20:00     06:10:00
#
#    DEPARTURE_DELAY  ARRIVAL_DELAY
# 0            -11.0          -22.0
# 1             -8.0           -9.0
# 2             -2.0            5.0
# 3             -5.0           -9.0
# 4             -1.0          -21.0
# 5             -5.0            8.0

# %% [markdown]
# ### Questions to be anwsered from the data set.

# %% [markdown]
# ###### 1) What airlines have the best and worst records for flight delay?

# %%
df.ARRIVAL_DELAY.mean()
# Out:
# 7.6121905034689075

# %% [markdown]
# This shows the mean (average) delay over all the airlines.
# That does not really tell us much.

# %%
mean_airline = df.groupby('AIRLINE') ['ARRIVAL_DELAY'].mean()
mean_airline.plot(kind = 'bar')

# %% [markdown]
# ##### After a couple basic commands, I see changes that need to be made.
# I want to build a graph that is easier to read. By adding the airline names and color.

# %%
abbr_companies = airlines_names.set_index('IATA_CODE')['AIRLINE'].to_dict()

# %%
colors = ['firebrick', 'gold', 'lightcoral', 'aquamarine', 'c', 'yellowgreen', 'grey',
          'seagreen', 'tomato', 'violet', 'wheat', 'chartreuse', 'lightskyblue', 'royalblue']

# %%
df2 = df.loc[:, ['AIRLINE', 'ARRIVAL_DELAY']]
df2['AIRLINE'] = df2['AIRLINE'].replace(abbr_companies)

ax = sns.stripplot(y="AIRLINE", x="ARRIVAL_DELAY", size = 7, palette = colors,
                    data=df2, linewidth = 0.5,  jitter=True)
plt.setp(ax.get_xticklabels(), fontsize=14)
plt.setp(ax.get_yticklabels(), fontsize=14)
ax.set_xticklabels(['{:2.0f}h{:2.0f}m'.format(*[int(y) for y in divmod(x,60)])
                         for x in ax.get_xticks()])
plt.xlabel('Flight delays', fontsize=18, bbox={'facecolor':'midnightblue', 'pad':5},
           color='w', labelpad=20)
ax.yaxis.label.set_visible(False)

# %% [markdown]
# ###### That is better. Now, we should look at the length of delay for each airline.

# %%
delay_length = lambda x:((0,1)[x > 5],2)[x > 45]
df['DELAY_LEVEL'] = df['ARRIVAL_DELAY'].apply(delay_length)
#____________________________________________________
fig = plt.figure(1, figsize=(10,7))
ax = sns.countplot(y="AIRLINE", hue='DELAY_LEVEL', data=df)
#____________________________________________________________________________________
# We replace the abbreviations by the full names of the companies and set the labels
labels = [abbr_companies[item.get_text()] for item in ax.get_yticklabels()]
ax.set_yticklabels(labels)
plt.setp(ax.get_xticklabels(), fontsize=12, weight = 'normal', rotation = 0);
plt.setp(ax.get_yticklabels(), fontsize=12, weight = 'bold', rotation = 0);
ax.yaxis.label.set_visible(False)
plt.xlabel('Flight count', fontsize=16, weight = 'bold', labelpad=10)
#________________
# Set the legend
L = plt.legend()
L.get_texts()[0].set_text('on time (t < 5 min)')
L.get_texts()[1].set_text('small delay (5 < t < 45 min)')
L.get_texts()[2].set_text('large delay (t > 45 min)')
plt.show()

# %% [markdown]
# ###### We can look at the difference of Departure delays and Arrival delays

# %%
mpl.rcParams.update(mpl.rcParamsDefault)
mpl.rcParams['hatch.linewidth'] = 2.0  

fig = plt.figure(1, figsize=(11,6))
ax = sns.barplot(x="DEPARTURE_DELAY", y="AIRLINE", data=df, color="lightskyblue", ci=None)
ax = sns.barplot(x="ARRIVAL_DELAY", y="AIRLINE", data=df, color="r", hatch = '///',
                 alpha = 0.0, ci=None)
labels = [abbr_companies[item.get_text()] for item in ax.get_yticklabels()]
ax.set_yticklabels(labels)
ax.yaxis.label.set_visible(False)
plt.xlabel('Mean delay [min] (@departure: blue, @arrival: hatch lines)',
           fontsize=14, weight = 'bold', labelpad=10);

# %% [markdown]
# ##### 2) What ten airports have the most late flights?

# %%
#find mean for airport delays
airport_mean_delays = pd.DataFrame(pd.Series(df['ORIGIN_AIRPORT'].unique()))
airport_mean_delays.set_index(0, drop = True, inplace = True)

for carrier in abbr_companies.keys():
    df1 = df[df['AIRLINE'] == carrier]
    test = df1['ARRIVAL_DELAY'].groupby(df['ORIGIN_AIRPORT']).apply(get_stats).unstack()
    airport_mean_delays[carrier] = test.loc[:, 'mean']

# %%
sns.set(context="paper")
fig = plt.figure(1, figsize=(8,8))

ax = fig.add_subplot(1,2,1)
subset = airport_mean_delays.iloc[:50,:].rename(columns = abbr_companies)
mask = subset.isnull()
sns.heatmap(subset, linewidths=0.01, cmap="Accent", mask=mask, vmin = 0, vmax = 35)
plt.setp(ax.get_xticklabels(), fontsize=10, rotation = 85) ;
ax.yaxis.label.set_visible(False)

ax = fig.add_subplot(1,2,2)    
subset = airport_mean_delays.iloc[50:100,:].rename(columns = abbr_companies)
fig.text(0.5, 1.02, "Delays: Origin Airport", ha='center', fontsize = 18)
mask = subset.isnull()
sns.heatmap(subset, linewidths=0.01, cmap="Accent", mask=mask, vmin = 0, vmax = 35)
plt.setp(ax.get_xticklabels(), fontsize=10, rotation = 85) ;
ax.yaxis.label.set_visible(False)

plt.tight_layout()

# %%
# Function that define how delays are grouped by flight length
Flight_length = lambda x:((0,60)[x > 60],120)[x > 120]
df['FLIGHT_LENGTH'] = df['SCHEDULED_TIME'].apply(Flight_length)
#____________________________________________________
fig = plt.figure(1, figsize=(10,7))
ax = sns.countplot(y="AIRLINE", hue='FLIGHT_LENGTH', data=df)
#____________________________________________________________________________________
# We replace the abbreviations by the full names of the companies and set the labels
labels = [abbr_companies[item.get_text()] for item in ax.get_yticklabels()]
ax.set_yticklabels(labels)
plt.setp(ax.get_xticklabels(), fontsize=12, weight = 'normal', rotation = 0);
plt.setp(ax.get_yticklabels(), fontsize=12, weight = 'bold', rotation = 0);
ax.yaxis.label.set_visible(False)
plt.xlabel('Flight count with Flight distance', fontsize=16, weight = 'bold', labelpad=10)
#________________
# Set the legend #Can d make clear
L = plt.legend()
L.get_texts()[0].set_text('Short (FT < 60 min)')
L.get_texts()[1].set_text('Medium (60 < FT < 120 min)')
L.get_texts()[2].set_text('Long (FT > 120 min)')
plt.show()
